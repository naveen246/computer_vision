# %%
import cv2
import numpy as np
import nbimporter

from hough_peaks import *
from hough_lines_acc import *
from hough_lines_draw import *
from hough_circles_acc import *
from hough_circles_draw import *
from find_circles import *
import util
# Out:
# Importing Jupyter notebook from hough_peaks.ipynb
# Importing Jupyter notebook from hough_lines_acc.ipynb
# Importing Jupyter notebook from util.ipynb
# Importing Jupyter notebook from hough_lines_draw.ipynb
# Importing Jupyter notebook from hough_circles_acc.ipynb
# Importing Jupyter notebook from hough_circles_draw.ipynb
# Importing Jupyter notebook from find_circles.ipynb

# %%
# 1. Edge image

img = util.read_img('ps1-input0.png')
img_edges = cv2.Canny(img, 0, 0)
util.write_img('ps1-1-a-1.png', img_edges)

util.show_images_together(img, img_edges)

# %%
# 2. Hough Transform for Lines

def highlight_hough_peaks(H, peaks):
    highlight_peaks = H.copy()
    for peak in peaks:
        row, col = peak
        cv2.circle(highlight_peaks, (col, row), 5, (255,255,255), -1)
    return highlight_peaks

H, rho, theta = hough_lines_acc(img_edges)
peaks = hough_peaks(H, 10);
highlight_peaks = highlight_hough_peaks(H, peaks)
util.write_img('ps1-2-a-1.png', H)
util.write_img('ps1-2-b-1.png', highlight_peaks)

util.show_images_together(H, highlight_peaks)

img_edge_colored = hough_lines_draw(img, 'ps1-2-c-1.png', peaks, rho, theta)
util.show_img(img_edge_colored)

# %%
# 3. Hough Transform for Lines on Noisy Image

noisy_img = util.read_img('ps1-input0-noise.png')
smooth_img = cv2.GaussianBlur(noisy_img, (23, 23), 5)
util.write_img('ps1-3-a-1.png', smooth_img)

util.show_images_together(noisy_img, smooth_img)

noisy_edge_img = cv2.Canny(noisy_img, 20, 40)
smooth_edge_img = cv2.Canny(smooth_img, 20, 40)
util.write_img('ps1-3-b-1.png', noisy_edge_img)
util.write_img('ps1-3-b-2.png', smooth_edge_img)

util.show_images_together(noisy_edge_img, smooth_edge_img)

H, rho, theta = hough_lines_acc(smooth_edge_img)
peaks = hough_peaks(H, 10);
highlight_peaks = highlight_hough_peaks(H, peaks)
util.write_img('ps1-3-c-1.png', highlight_peaks)

util.show_images_together(H, highlight_peaks)
img_edge_colored = hough_lines_draw(noisy_img, 'ps1-3-c-2.png', peaks, rho, theta)
util.show_img(img_edge_colored)

# %%
# 4. Hough Transform for Lines on a more Complex Image

img = util.read_img_gray_mode('ps1-input1.png')
smooth_img = cv2.GaussianBlur(img, (31, 31), 0)
util.write_img('ps1-4-a-1.png', smooth_img)

util.show_images_together(img, smooth_img)
smooth_edge_img = cv2.Canny(smooth_img, 30, 30)
util.write_img('ps1-4-b-1.png', smooth_edge_img)

H, rho, theta = hough_lines_acc(smooth_edge_img)
peaks = hough_peaks(H, 10, threshold=70, nhood_size=10);
highlight_peaks = highlight_hough_peaks(H, peaks)
util.write_img('ps1-4-c-1.png', highlight_peaks)

util.show_images_together(H, highlight_peaks)
img_edge_colored = hough_lines_draw(img, 'ps1-4-c-2.png', peaks, rho, theta, (255,255,255))
util.show_images_together(smooth_edge_img, img_edge_colored)

# %%
# 5. Hough Transform for Circles

img = util.read_img_gray_mode('ps1-input1.png')
smooth_img = cv2.GaussianBlur(img, (11, 11), 3)
util.write_img('ps1-5-a-1.png', smooth_img)

util.show_images_together(img, smooth_img)
smooth_edge_img = cv2.Canny(smooth_img, 50, 50)
util.write_img('ps1-5-a-2.png', smooth_edge_img)

radius = 20
H = hough_circles_acc(smooth_edge_img, radius)
centers = hough_peaks(H, numpeaks=10, threshold=140, nhood_size=100)
img_circles = img.copy()
img_circles = hough_circles_draw(img_circles, centers, radius, (0,0,255))
util.write_img('ps1-5-a-3.png', img_circles)
util.show_images_together(smooth_edge_img, img_circles)

# 5b: detect circles in the range [20 50]
centers, radii = find_circles(smooth_edge_img, [20, 50], threshold=153, nhood_size=10)
img_circles = img.copy()
for i in range(len(radii)):
    img_circles = hough_circles_draw(img_circles, centers[i], radii[i])
util.write_img('ps1-5-b-1.png', img_circles)
util.show_img(img_circles)
# Out:
# Progress: 0% - Circles: 1
# Progress: 3% - Circles: 4
# Progress: 6% - Circles: 4
# Progress: 10% - Circles: 7
# Progress: 13% - Circles: 9
# Progress: 16% - Circles: 10
# Progress: 20% - Circles: 11
# Progress: 23% - Circles: 13
# Progress: 26% - Circles: 13
# Progress: 30% - Circles: 13
# Progress: 33% - Circles: 13
# Progress: 36% - Circles: 13
# Progress: 40% - Circles: 13
# Progress: 43% - Circles: 13
# Progress: 46% - Circles: 13
# Progress: 50% - Circles: 13
# Progress: 53% - Circles: 13
# Progress: 56% - Circles: 13
# Progress: 60% - Circles: 13
# Progress: 63% - Circles: 13
# Progress: 66% - Circles: 13
# Progress: 70% - Circles: 13
# Progress: 73% - Circles: 13
# Progress: 76% - Circles: 13
# Progress: 80% - Circles: 13
# Progress: 83% - Circles: 13
# Progress: 86% - Circles: 13
# Progress: 90% - Circles: 13
# Progress: 93% - Circles: 13
# Progress: 96% - Circles: 13
